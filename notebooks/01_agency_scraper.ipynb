# %% [markdown]
# ### 🐶 Load & Inspect Agency Mapping for D.O.G.E.
#
# > The agency-to-regulation mapping is retrieved from the [agencies.json](https://www.ecfr.gov/developers/documentation/api/v1) endpoint of the Electronic Code of Federal Regulations (eCFR).
#
# > While no explicit timestamp is provided in the API response, the data structure appears to reflect 2024 mappings, according to [DOGE's regulations sources](https://doge.gov/regulations).
#
# > This mapping includes all top-level agencies (sorted by name), along with their respective child agencies, and serves as the foundation for linking CFR titles, chapters, and parts to their governing authorities.

# %% [markdown]
# ### 🔎 Inspect API Output via CLI
#
# > For a quick command-line inspection of the eCFR `agencies.json` response:
#
# > ```bash
# > curl -X GET "https://www.ecfr.gov/api/admin/v1/agencies.json" -H "accept: application/json" | jq .
# > ```
#
# > This fetches the agency mapping JSON directly and pretty-prints it using `jq`.
# > Grep for keywords, detect patterns, or understand the structure before processing it in Python.

# %% [markdown]
# ```json
# {
#   "agencies": [
#     {
#       "name": "Department of Agriculture",
#       "slug": "agriculture-department",
#       "children": [
#         {
#           "name": "Agricultural Marketing Service",
#           "slug": "agricultural-marketing-service",
#           "cfr_references": [
#             {
#               "title": 7,
#               "chapter": "I"
#             },
#             ...  // child cfr_references
#           ]
#         },
#         ...     // siblings
#       ],
#       "cfr_references": [
#         {
#           "title": 2,
#           "chapter": "IV"
#         },
#         {
#           "title": 5,
#           "chapter": "LXXIII"
#         },
#         ...   // parent cfr_references
#       ]
#     },
#     ...   // agencies
#   ]
# }
# ```

# %% [markdown]
# #### API Structure Overview
#
# > The root key is `agencies`, a list of agency dictionaries. Each agency has:
# > - Metadata (`name`, `slug`, etc.)
# > - `cfr_references` → used to extract regulation text
# > - Optional `children` → same structure, no nested children
#
# > Nested hierarchy to process:
# > `agencies` → `children` (if any) → `cfr_references`
#
# > 🔥🔥 Flattening `agencies` + `children` + their `cfr_references` builds the dataset for downstream analysis.

# %%
from doge_data_challenge.helpers.env_setup import setup_env
from doge_data_challenge.helpers.print_helpers import shorten_path

# Initialize environment config
try:
    paths, config = setup_env()
except FileNotFoundError as e:
    print(f"Error: {e}")
    print("Ensure .env file exists in the project root with required configuration")
    raise

# Access paths/config
#snapshot_date        = config["SNAPSHOT_DATE"]       # i.e. 2025-03-27
agency_metadata_path = paths["AGENCY_METADATA_PATH"]  # i.e. ~/repo/doge-data-challenge/agency_metadata/{SNAPSHOT_DATE}

# Define output file path
filename_json = agency_metadata_path / "agencies_snapshot.json"

# Print config for verification
#print(f"Snapshot Date: {snapshot_date}")
#print(f"Agency Metadata Path: {shorten_path(agency_metadata_path)}")
print(f"Agency Metadata Filename: {shorten_path(filename_json)}")

# Debug: Print sys.path 
#print("\nSystem Paths:")
#for p in sys.path:
#    print(shorten_path(p))
# Out:
# Agency Metadata Filename: ~/repo/doge-data-challenge/agency_metadata/2025-03-27/agencies_snapshot.json

# %%
import os
import sys
import json
import requests
from pathlib import Path
from datetime import datetime


# API endpoint for agency metadata
url = "https://www.ecfr.gov/api/admin/v1/agencies.json"


# Fetch agency metadata
try:
    response = requests.get(url, timeout=10)
    response.raise_for_status()  # Raises HTTPError for 4xx/5xx status codes
    data = response.json()
except requests.exceptions.HTTPError as e:
    print(f"HTTP Error fetching agency metadata: {e}\n")
    raise
except requests.exceptions.ConnectionError as e:
    print(f"Connection Error fetching agency metadata: {e}\n")
    raise
except requests.exceptions.Timeout as e:
    print(f"Timeout Error fetching agency metadata: {e}\n")
    raise
except requests.exceptions.RequestException as e:
    print(f"Error fetching agency metadata: {e}\n")
    raise


# Save JSON to file
try:
    with open(filename_json, "w") as f:
        json.dump(data, f, indent=2)
    print(f"Saved snapshot of agency JSON to {shorten_path(filename_json)}\n")
except OSError as e:
    print(f"Error saving JSON to {shorten_path(filename_json)}: {e}\n")
    raise

# Optional: Print JSON for debugging (uncomment if needed)
print(json.dumps(data, indent=2))
# Out:
# Saved snapshot of agency JSON to ~/repo/doge-data-challenge/agency_metadata/2025-03-27/agencies_snapshot.json
#
# {
#   "agencies": [
#     {
#       "name": "Administrative Conference of the United States",
#       "short_name": "ACUS",
#       "display_name": "Administrative Conference of the United States",
#       "sortable_name": "Administrative Conference of the United States",
#       "slug": "administrative-conference-of-the-united-states",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 1,
#           "chapter": "III"
#         }
#       ]
#     },
#     {
#       "name": "Advisory Council on Historic Preservation",
#       "short_name": "ACHP",
#       "display_name": "Advisory Council on Historic Preservation",
#       "sortable_name": "Advisory Council on Historic Preservation",
#       "slug": "advisory-council-on-historic-preservation",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 36,
#           "chapter": "VIII"
#         }
#       ]
#     },
#     {
#       "name": "Special Inspector General for Afghanistan Reconstruction",
#       "short_name": "SIGAR",
#       "display_name": "Special Inspector General for Afghanistan Reconstruction",
#       "sortable_name": "Afghanistan Reconstruction, Special Inspector General for",
#       "slug": "special-inspector-general-for-afghanistan-reconstruction",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 5,
#           "chapter": "LXXXIII"
#         }
#       ]
#     },
#     {
#       "name": "African Development Foundation",
#       "short_name": "USADF",
#       "display_name": "African Development Foundation",
#       "sortable_name": "African Development Foundation",
#       "slug": "african-development-foundation",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 22,
#           "chapter": "XV"
#         },
#         {
#           "title": 48,
#           "chapter": "57"
#         }
#       ]
#     },
#     {
#       "name": "United States Agency for Global Media",
#       "short_name": "USAGM",
#       "display_name": "United States Agency for Global Media",
#       "sortable_name": "Agency for Global Media, United States",
#       "slug": "united-states-agency-for-global-media",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 22,
#           "chapter": "V"
#         },
#         {
#           "title": 48,
#           "chapter": "19"
#         }
#       ]
#     },
#     {
#       "name": "Department of Agriculture",
#       "short_name": "USDA",
#       "display_name": "Department of Agriculture",
#       "sortable_name": "Agriculture, Department of",
#       "slug": "agriculture-department",
#       "children": [
#         {
#           "name": "Agricultural Marketing Service",
#           "short_name": "AMS",
#           "display_name": "Agricultural Marketing Service, Department of Agriculture",
#           "sortable_name": "Agricultural Marketing Service",
#           "slug": "agricultural-marketing-service",
#           "cfr_references": [
#             {
#               "title": 7,
#               "chapter": "I"
#             },
#             {
#               "title": 7,
#               "chapter": "VIII"
#             },
#             {
#               "title": 7,
#               "chapter": "IX"
#             },
#             {
#               "title": 7,
#               "chapter": "X"
#             },
#             {
#               "title": 7,
#               "chapter": "XI"
#             },
#             {
#               "title": 9,
#               "chapter": "II"
#             }
#           ]
#         },
#         {
#           "name": "Agricultural Research Service",
#           "short_name": "ARS",
#           "display_name": "Agricultural Research Service, Department of Agriculture",
#           "sortable_name": "Agricultural Research Service",
#           "slug": "agricultural-research-service",
#           "cfr_references": [
#             {
#               "title": 7,
#               "chapter": "V"
#             }
#           ]
#         },
#         {
#           "name": "Animal and Plant Health Inspection Service",
#           "short_name": "APHIS",
#           "display_name": "Animal and Plant Health Inspection Service, Department of Agriculture",
#           "sortable_name": "Animal and Plant Health Inspection Service",
#           "slug": "animal-and-plant-health-inspection-service",
#           "cfr_references": [
#             {
#               "title": 7,
#               "chapter": "III"
#             },
#             {
#               "title": 9,
#               "chapter": "I"
#             }
#           ]
#         },
#         {
#           "name": "Commodity Credit Corporation",
#           "short_name": "CCC",
#           "display_name": "Commodity Credit Corporation, Department of Agriculture",
#           "sortable_name": "Commodity Credit Corporation",
#           "slug": "commodity-credit-corporation",
#           "cfr_references": [
#             {
#               "title": 7,
#               "chapter": "XIV"
#             }
#           ]
#         },
#         {
#           "name": "Economic Research Service",
#           "short_name": "ERS",
#           "display_name": "Economic Research Service, Department of Agriculture",
#           "sortable_name": "Economic Research Service",
#           "slug": "economic-research-service",
#           "cfr_references": [
#             {
#               "title": 7,
#               "chapter": "XXXVII"
#             }
#           ]
#         },
#         {
#           "name": "Farm Service Agency",
#           "short_name": "FSA",
#           "display_name": "Farm Service Agency, Department of Agriculture",
#           "sortable_name": "Farm Service Agency",
#           "slug": "farm-service-agency",
#           "cfr_references": [
#             {
#               "title": 7,
#               "chapter": "VII"
#             }
#           ]
#         },
#         {
#           "name": "Federal Crop Insurance Corporation",
#           "short_name": "FCIC",
#           "display_name": "Federal Crop Insurance Corporation, Department of Agriculture",
#           "sortable_name": "Federal Crop Insurance Corporation",
#           "slug": "federal-crop-insurance-corporation",
#           "cfr_references": [
#             {
#               "title": 7,
#               "chapter": "IV"
#             }
#           ]
#         },
#         {
#           "name": "Food and Nutrition Service",
#           "short_name": "FNS",
#           "display_name": "Food and Nutrition Service, Department of Agriculture",
#           "sortable_name": "Food and Nutrition Service",
#           "slug": "food-and-nutrition-service",
#           "cfr_references": [
#             {
#               "title": 7,
#               "chapter": "II"
#             }
#           ]
#         },
#         {
#           "name": "Food Safety and Inspection Service",
#           "short_name": "FSIS",
#           "display_name": "Food Safety and Inspection Service, Department of Agriculture",
#           "sortable_name": "Food Safety and Inspection Service",
#           "slug": "food-safety-and-inspection-service",
#           "cfr_references": [
#             {
#               "title": 9,
#               "chapter": "III"
#             }
#           ]
#         },
#         {
#           "name": "Foreign Agricultural Service",
#           "short_name": "FAS",
#           "display_name": "Foreign Agricultural Service, Department of Agriculture",
#           "sortable_name": "Foreign Agricultural Service",
#           "slug": "foreign-agricultural-service",
#           "cfr_references": [
#             {
#               "title": 7,
#               "chapter": "XV"
#             }
#           ]
#         },
#         {
#           "name": "Forest Service",
#           "short_name": "FS",
#           "display_name": "Forest Service, Department of Agriculture",
#           "sortable_name": "Forest Service",
#           "slug": "forest-service",
#           "cfr_references": [
#             {
#               "title": 36,
#               "chapter": "II"
#             }
#           ]
#         },
#         {
#           "name": "National Agricultural Statistics Service",
#           "short_name": "NASS",
#           "display_name": "National Agricultural Statistics Service, Department of Agriculture",
#           "sortable_name": "National Agricultural Statistics Service",
#           "slug": "national-agricultural-statistics-service",
#           "cfr_references": [
#             {
#               "title": 7,
#               "chapter": "XXXVI"
#             }
#           ]
#         },
#         {
#           "name": "National Institute of Food and Agriculture",
#           "short_name": "NIFA",
#           "display_name": "National Institute of Food and Agriculture, Department of Agriculture",
#           "sortable_name": "National Institute of Food and Agriculture",
#           "slug": "national-institute-of-food-and-agriculture",
#           "cfr_references": [
#             {
#               "title": 7,
#               "chapter": "XXXIV"
#             }
#           ]
#         },
#         {
#           "name": "Natural Resources Conservation Service",
#           "short_name": "NRCS",
#           "display_name": "Natural Resources Conservation Service, Department of Agriculture",
#           "sortable_name": "Natural Resources Conservation Service",
#           "slug": "natural-resources-conservation-service",
#           "cfr_references": [
#             {
#               "title": 7,
#               "chapter": "VI"
#             }
#           ]
#         },
#         {
#           "name": "Office of Advocacy and Outreach",
#           "short_name": "OAO",
#           "display_name": "Office of Advocacy and Outreach, Department of Agriculture",
#           "sortable_name": "Advocacy and Outreach, Office of",
#           "slug": "advocacy-and-outreach-office",
#           "cfr_references": [
#             {
#               "title": 7,
#               "chapter": "XXV"
#             }
#           ]
#         },
#         {
#           "name": "Office of Chief Financial Officer",
#           "short_name": null,
#           "display_name": "Office of Chief Financial Officer, Department of Agriculture",
#           "sortable_name": "Chief Financial Officer, Office of",
#           "slug": "office-of-the-chief-financial-officer-agriculture-department",
#           "cfr_references": [
#             {
#               "title": 7,
#               "chapter": "XXX"
#             }
#           ]
#         },
#         {
#           "name": "Office of Energy Policy and New Uses",
#           "short_name": "OEPNU",
#           "display_name": "Office of Energy Policy and New Uses, Department of Agriculture",
#           "sortable_name": "Energy Policy and New Uses, Office of",
#           "slug": "energy-policy-and-new-uses-office",
#           "cfr_references": [
#             {
#               "title": 7,
#               "chapter": "XXIX"
#             }
#           ]
#         },
#         {
#           "name": "Office of Environmental Quality",
#           "short_name": "",
#           "display_name": "Office of Environmental Quality, Department of Agriculture",
#           "sortable_name": "Environmental Quality, Office of",
#           "slug": "office-of-environmental-quality",
#           "cfr_references": [
#             {
#               "title": 7,
#               "chapter": "XXXI"
#             }
#           ]
#         },
#         {
#           "name": "Office of Information Resources Management",
#           "short_name": "",
#           "display_name": "Office of Information Resources Management, Department of Agriculture",
#           "sortable_name": "Information Resources Management, Office of",
#           "slug": "office-of-information-resources-management",
#           "cfr_references": [
#             {
#               "title": 7,
#               "chapter": "XXVII"
#             }
#           ]
#         },
#         {
#           "name": "Office of Inspector General",
#           "short_name": "OIG USDA",
#           "display_name": "Office of Inspector General, Department of Agriculture",
#           "sortable_name": "Inspector General, Office of",
#           "slug": "inspector-general-office-agriculture-department",
#           "cfr_references": [
#             {
#               "title": 7,
#               "chapter": "XXVI"
#             }
#           ]
#         },
#         {
#           "name": "Office of Operations",
#           "short_name": "",
#           "display_name": "Office of Operations, Department of Agriculture",
#           "sortable_name": "Operations, Office of",
#           "slug": "office-of-operations",
#           "cfr_references": [
#             {
#               "title": 7,
#               "chapter": "XXVIII"
#             }
#           ]
#         },
#         {
#           "name": "Office of Procurement and Property Management",
#           "short_name": "OPPM",
#           "display_name": "Office of Procurement and Property Management, Department of Agriculture",
#           "sortable_name": "Procurement and Property Management, Office of",
#           "slug": "procurement-and-property-management-office-of",
#           "cfr_references": [
#             {
#               "title": 7,
#               "chapter": "XXXII"
#             }
#           ]
#         },
#         {
#           "name": "Office of Secretary of Agriculture",
#           "short_name": "",
#           "display_name": "Office of Secretary of Agriculture, Department of Agriculture",
#           "sortable_name": "Secretary of Agriculture, Office of",
#           "slug": "office-of-secretary-of-agriculture",
#           "cfr_references": [
#             {
#               "title": 7,
#               "subtitle": "A"
#             }
#           ]
#         },
#         {
#           "name": "Office of Transportation",
#           "short_name": null,
#           "display_name": "Office of Transportation, Department of Agriculture",
#           "sortable_name": "Transportation, Office of",
#           "slug": "transportation-office",
#           "cfr_references": [
#             {
#               "title": 7,
#               "chapter": "XXXIII"
#             }
#           ]
#         },
#         {
#           "name": "Rural Business-Cooperative Service",
#           "short_name": "RBS",
#           "display_name": "Rural Business-Cooperative Service, Department of Agriculture",
#           "sortable_name": "Rural Business-Cooperative Service",
#           "slug": "rural-business-cooperative-service",
#           "cfr_references": [
#             {
#               "title": 7,
#               "chapter": "XVIII"
#             },
#             {
#               "title": 7,
#               "chapter": "XLII"
#             },
#             {
#               "title": 7,
#               "chapter": "L"
#             }
#           ]
#         },
#         {
#           "name": "Rural Housing Service",
#           "short_name": "RHS",
#           "display_name": "Rural Housing Service, Department of Agriculture",
#           "sortable_name": "Rural Housing Service",
#           "slug": "rural-housing-service",
#           "cfr_references": [
#             {
#               "title": 7,
#               "chapter": "XVIII"
#             },
#             {
#               "title": 7,
#               "chapter": "XXXV"
#             },
#             {
#               "title": 7,
#               "chapter": "L"
#             }
#           ]
#         },
#         {
#           "name": "Rural Utilities Service",
#           "short_name": "RUS",
#           "display_name": "Rural Utilities Service, Department of Agriculture",
#           "sortable_name": "Rural Utilities Service",
#           "slug": "rural-utilities-service",
#           "cfr_references": [
#             {
#               "title": 7,
#               "chapter": "XVII"
#             },
#             {
#               "title": 7,
#               "chapter": "XVIII"
#             },
#             {
#               "title": 7,
#               "chapter": "XLII"
#             },
#             {
#               "title": 7,
#               "chapter": "L"
#             }
#           ]
#         },
#         {
#           "name": "World Agricultural Outlook Board",
#           "short_name": null,
#           "display_name": "World Agricultural Outlook Board, Department of Agriculture",
#           "sortable_name": "World Agricultural Outlook Board",
#           "slug": "world-agricultural-outlook-board",
#           "cfr_references": [
#             {
#               "title": 7,
#               "chapter": "XXXVIII"
#             }
#           ]
#         }
#       ],
#       "cfr_references": [
#         {
#           "title": 2,
#           "chapter": "IV"
#         },
#         {
#           "title": 5,
#           "chapter": "LXXIII"
#         },
#         {
#           "title": 7,
#           "chapter": "XVI"
#         },
#         {
#           "title": 7,
#           "chapter": "XX"
#         },
#         {
#           "title": 48,
#           "chapter": "4"
#         }
#       ]
#     },
#     {
#       "name": "Air Transportation System Stabilization",
#       "short_name": "ATSB",
#       "display_name": "Air Transportation System Stabilization",
#       "sortable_name": "Air Transportation System Stabilization",
#       "slug": "air-transportation-stabilization-board",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 14,
#           "chapter": "VI"
#         }
#       ]
#     },
#     {
#       "name": "American Battle Monuments Commission",
#       "short_name": "ABMC",
#       "display_name": "American Battle Monuments Commission",
#       "sortable_name": "American Battle Monuments Commission",
#       "slug": "american-battle-monuments-commission",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 36,
#           "chapter": "IV"
#         }
#       ]
#     },
#     {
#       "name": "Appalachian Regional Commission",
#       "short_name": "ARC",
#       "display_name": "Appalachian Regional Commission",
#       "sortable_name": "Appalachian Regional Commission",
#       "slug": "appalachian-regional-commission",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 5,
#           "chapter": "IX"
#         }
#       ]
#     },
#     {
#       "name": "Architectural and Transportation Barriers Compliance Board",
#       "short_name": "ATBCB",
#       "display_name": "Architectural and Transportation Barriers Compliance Board",
#       "sortable_name": "Architectural and Transportation Barriers Compliance Board",
#       "slug": "architectural-and-transportation-barriers-compliance-board",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 36,
#           "chapter": "XI"
#         }
#       ]
#     },
#     {
#       "name": "Arctic Research Commission",
#       "short_name": "ARCTIC",
#       "display_name": "Arctic Research Commission",
#       "sortable_name": "Arctic Research Commission",
#       "slug": "arctic-research-commission",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 45,
#           "chapter": "XXIII"
#         }
#       ]
#     },
#     {
#       "name": "Armed Forces Retirement Home",
#       "short_name": "AFRH",
#       "display_name": "Armed Forces Retirement Home",
#       "sortable_name": "Armed Forces Retirement Home",
#       "slug": "armed-forces-retirement-home",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 5,
#           "chapter": "XI"
#         },
#         {
#           "title": 38,
#           "chapter": "II"
#         }
#       ]
#     },
#     {
#       "name": "Committee for Purchase From People Who Are Blind or Severely Disabled",
#       "short_name": "CPPBSD",
#       "display_name": "Committee for Purchase From People Who Are Blind or Severely Disabled",
#       "sortable_name": "Blind or Severely Disabled, Committee for Purchase from People Who Are",
#       "slug": "committee-for-purchase-from-people-who-are-blind-or-severely-disabled",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 41,
#           "chapter": "51"
#         }
#       ]
#     },
#     {
#       "name": "Central Intelligence Agency",
#       "short_name": "CIA",
#       "display_name": "Central Intelligence Agency",
#       "sortable_name": "Central Intelligence Agency",
#       "slug": "central-intelligence-agency",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 32,
#           "chapter": "XIX"
#         }
#       ]
#     },
#     {
#       "name": "Chemical Safety and Hazard Investigation Board",
#       "short_name": "CSB",
#       "display_name": "Chemical Safety and Hazard Investigation Board",
#       "sortable_name": "Chemical Safety and Hazard Investigation Board",
#       "slug": "chemical-safety-and-hazard-investigation-board",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 40,
#           "chapter": "VI"
#         }
#       ]
#     },
#     {
#       "name": "Commission on Civil Rights",
#       "short_name": "CRC",
#       "display_name": "Commission on Civil Rights",
#       "sortable_name": "Civil Rights, Commission on",
#       "slug": "civil-rights-commission",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 5,
#           "chapter": "LXVIII"
#         },
#         {
#           "title": 45,
#           "chapter": "VII"
#         }
#       ]
#     },
#     {
#       "name": "Department of Commerce",
#       "short_name": "DOC",
#       "display_name": "Department of Commerce",
#       "sortable_name": "Commerce, Department of",
#       "slug": "commerce-department",
#       "children": [
#         {
#           "name": "Bureau of Census",
#           "short_name": "USBC",
#           "display_name": "Bureau of Census, Department of Commerce",
#           "sortable_name": "Census, Bureau of",
#           "slug": "census-bureau",
#           "cfr_references": [
#             {
#               "title": 15,
#               "chapter": "I"
#             }
#           ]
#         },
#         {
#           "name": "Bureau of Economic Analysis",
#           "short_name": "EAB",
#           "display_name": "Bureau of Economic Analysis, Department of Commerce",
#           "sortable_name": "Economic Analysis, Bureau of",
#           "slug": "economic-analysis-bureau",
#           "cfr_references": [
#             {
#               "title": 15,
#               "chapter": "VIII"
#             }
#           ]
#         },
#         {
#           "name": "Bureau of Industry and Security",
#           "short_name": "BIS",
#           "display_name": "Bureau of Industry and Security, Department of Commerce",
#           "sortable_name": "Industry and Security, Bureau of",
#           "slug": "industry-and-security-bureau",
#           "cfr_references": [
#             {
#               "title": 15,
#               "chapter": "VII"
#             }
#           ]
#         },
#         {
#           "name": "Economic Development Administration",
#           "short_name": "EDA",
#           "display_name": "Economic Development Administration, Department of Commerce",
#           "sortable_name": "Economic Development Administration",
#           "slug": "economic-development-administration",
#           "cfr_references": [
#             {
#               "title": 13,
#               "chapter": "III"
#             }
#           ]
#         },
#         {
#           "name": "Foreign-Trade Zones Board",
#           "short_name": "FTZB",
#           "display_name": "Foreign-Trade Zones Board, Department of Commerce",
#           "sortable_name": "Foreign-Trade Zones Board",
#           "slug": "foreign-trade-zones-board",
#           "cfr_references": [
#             {
#               "title": 15,
#               "chapter": "IV"
#             }
#           ]
#         },
#         {
#           "name": "International Trade Administration",
#           "short_name": "ITA",
#           "display_name": "International Trade Administration, Department of Commerce",
#           "sortable_name": "International Trade Administration",
#           "slug": "international-trade-administration",
#           "cfr_references": [
#             {
#               "title": 15,
#               "chapter": "III"
#             },
#             {
#               "title": 19,
#               "chapter": "III"
#             }
#           ]
#         },
#         {
#           "name": "Minority Business Development Agency",
#           "short_name": "MBDA",
#           "display_name": "Minority Business Development Agency, Department of Commerce",
#           "sortable_name": "Minority Business Development Agency",
#           "slug": "minority-business-development-agency",
#           "cfr_references": [
#             {
#               "title": 15,
#               "chapter": "XIV"
#             }
#           ]
#         },
#         {
#           "name": "National Institute of Standards and Technology",
#           "short_name": "NIST",
#           "display_name": "National Institute of Standards and Technology, Department of Commerce",
#           "sortable_name": "National Institute of Standards and Technology",
#           "slug": "national-institute-of-standards-and-technology",
#           "cfr_references": [
#             {
#               "title": 15,
#               "chapter": "II"
#             },
#             {
#               "title": 37,
#               "chapter": "IV"
#             }
#           ]
#         },
#         {
#           "name": "National Oceanic and Atmospheric Administration",
#           "short_name": "NOAA",
#           "display_name": "National Oceanic and Atmospheric Administration, Department of Commerce",
#           "sortable_name": "National Oceanic and Atmospheric Administration",
#           "slug": "national-oceanic-and-atmospheric-administration",
#           "cfr_references": [
#             {
#               "title": 15,
#               "chapter": "IX"
#             },
#             {
#               "title": 50,
#               "chapter": "III"
#             },
#             {
#               "title": 50,
#               "chapter": "IV"
#             }
#           ]
#         },
#         {
#           "name": "National Oceanic and Atmospheric Administration National Marine Fisheries Service",
#           "short_name": "",
#           "display_name": "National Oceanic and Atmospheric Administration National Marine Fisheries Service, Department of Commerce",
#           "sortable_name": "National Marine Fisheries Service, National Oceanic and Atmospheric Administration",
#           "slug": "national-oceanic-and-atmospheric-administration-national-marine-fisheries-service",
#           "cfr_references": [
#             {
#               "title": 50,
#               "chapter": "II"
#             }
#           ]
#         },
#         {
#           "name": "National Technical Information Service",
#           "short_name": "NTIS",
#           "display_name": "National Technical Information Service, Department of Commerce",
#           "sortable_name": "National Technical Information Service",
#           "slug": "national-technical-information-service",
#           "cfr_references": [
#             {
#               "title": 15,
#               "chapter": "XI"
#             }
#           ]
#         },
#         {
#           "name": "National Telecommunications and Information Administration",
#           "short_name": "NTIA",
#           "display_name": "National Telecommunications and Information Administration, Department of Commerce",
#           "sortable_name": "National Telecommunications and Information Administration",
#           "slug": "national-telecommunications-and-information-administration",
#           "cfr_references": [
#             {
#               "title": 15,
#               "chapter": "XXIII"
#             },
#             {
#               "title": 47,
#               "chapter": "III"
#             },
#             {
#               "title": 47,
#               "chapter": "IV"
#             }
#           ]
#         },
#         {
#           "name": "Office of Secretary of Commerce",
#           "short_name": "",
#           "display_name": "Office of Secretary of Commerce, Department of Commerce",
#           "sortable_name": "Secretary of Commerce, Office of",
#           "slug": "office-of-secretary-of-commerce",
#           "cfr_references": [
#             {
#               "title": 15,
#               "subtitle": "A"
#             }
#           ]
#         },
#         {
#           "name": "Office of Under-Secretary for Economic Affairs",
#           "short_name": "OUSEA",
#           "display_name": "Office of Under-Secretary for Economic Affairs, Department of Commerce",
#           "sortable_name": "Under-Secretary for Economic Affairs, Office of",
#           "slug": "under-secretary-for-economic-affairs",
#           "cfr_references": [
#             {
#               "title": 15,
#               "chapter": "XV"
#             }
#           ]
#         },
#         {
#           "name": "United States Patent and Trademark Office",
#           "short_name": "PTO",
#           "display_name": "United States Patent and Trademark Office, Department of Commerce",
#           "sortable_name": "Patent and Trademark Office, United States",
#           "slug": "patent-and-trademark-office",
#           "cfr_references": [
#             {
#               "title": 37,
#               "chapter": "I"
#             }
#           ]
#         }
#       ],
#       "cfr_references": [
#         {
#           "title": 2,
#           "chapter": "XIII"
#         },
#         {
#           "title": 44,
#           "chapter": "IV"
#         },
#         {
#           "title": 48,
#           "chapter": "13"
#         }
#       ]
#     },
#     {
#       "name": "Commodity Futures Trading Commission",
#       "short_name": "CFTC",
#       "display_name": "Commodity Futures Trading Commission",
#       "sortable_name": "Commodity Futures Trading Commission",
#       "slug": "commodity-futures-trading-commission",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 5,
#           "chapter": "XLI"
#         },
#         {
#           "title": 17,
#           "chapter": "I"
#         }
#       ]
#     },
#     {
#       "name": "Construction Industry Collective Bargaining Commission",
#       "short_name": null,
#       "display_name": "Construction Industry Collective Bargaining Commission",
#       "sortable_name": "Construction Industry Collective Bargaining Commission",
#       "slug": "construction-industry-collective-bargaining-commission",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 29,
#           "chapter": "IX"
#         }
#       ]
#     },
#     {
#       "name": "Consumer Financial Protection Bureau",
#       "short_name": "CFPB",
#       "display_name": "Consumer Financial Protection Bureau",
#       "sortable_name": "Consumer Financial Protection Bureau",
#       "slug": "consumer-financial-protection-bureau",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 5,
#           "chapter": "LXXXIV"
#         },
#         {
#           "title": 12,
#           "chapter": "X"
#         }
#       ]
#     },
#     {
#       "name": "Consumer Product Safety Commission",
#       "short_name": "CPSC",
#       "display_name": "Consumer Product Safety Commission",
#       "sortable_name": "Consumer Product Safety Commission",
#       "slug": "consumer-product-safety-commission",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 5,
#           "chapter": "LXXI"
#         },
#         {
#           "title": 16,
#           "chapter": "II"
#         }
#       ]
#     },
#     {
#       "name": "Council of the Inspectors General on Integrity and Efficiency",
#       "short_name": "CIGIE",
#       "display_name": "Council of the Inspectors General on Integrity and Efficiency",
#       "sortable_name": "Council of the Inspectors General on Integrity and Efficiency",
#       "slug": "council-of-the-inspectors-general-on-integrity-and-efficiency",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 5,
#           "chapter": "XCVIII"
#         }
#       ]
#     },
#     {
#       "name": "Court Services and Offender Supervision Agency for the District of Columbia",
#       "short_name": "CSOSA",
#       "display_name": "Court Services and Offender Supervision Agency for the District of Columbia",
#       "sortable_name": "Court Services and Offender Supervision Agency for the District of Columbia",
#       "slug": "court-services-and-offender-supervision-agency-for-the-district-of-columbia",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 5,
#           "chapter": "LXX"
#         },
#         {
#           "title": 28,
#           "chapter": "VIII"
#         }
#       ]
#     },
#     {
#       "name": "Defense Nuclear Facilities Safety Board",
#       "short_name": "DNFSB",
#       "display_name": "Defense Nuclear Facilities Safety Board",
#       "sortable_name": "Defense Nuclear Facilities Safety Board",
#       "slug": "defense-nuclear-facilities-safety-board",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 10,
#           "chapter": "XVII"
#         }
#       ]
#     },
#     {
#       "name": "Department of Defense",
#       "short_name": "DOD",
#       "display_name": "Department of Defense",
#       "sortable_name": "Defense, Department of",
#       "slug": "defense-department",
#       "children": [
#         {
#           "name": "Army Corps of Engineers",
#           "short_name": "COE",
#           "display_name": "Army Corps of Engineers, Department of Defense",
#           "sortable_name": "Corps of Engineers",
#           "slug": "engineers-corps",
#           "cfr_references": [
#             {
#               "title": 33,
#               "chapter": "II"
#             },
#             {
#               "title": 36,
#               "chapter": "III"
#             }
#           ]
#         },
#         {
#           "name": "Defense Acquisition Regulations System",
#           "short_name": "DARS",
#           "display_name": "Defense Acquisition Regulations System, Department of Defense",
#           "sortable_name": "Defense Acquisition Regulations System",
#           "slug": "defense-acquisition-regulations-system",
#           "cfr_references": [
#             {
#               "title": 48,
#               "chapter": "2"
#             }
#           ]
#         },
#         {
#           "name": "Defense Logistics Agency",
#           "short_name": "DLA",
#           "display_name": "Defense Logistics Agency, Department of Defense",
#           "sortable_name": "Defense Logistics Agency",
#           "slug": "defense-logistics-agency",
#           "cfr_references": [
#             {
#               "title": 32,
#               "chapter": "XII"
#             },
#             {
#               "title": 48,
#               "chapter": "54"
#             }
#           ]
#         },
#         {
#           "name": "Department of Navy Acquisition Regulations",
#           "short_name": "",
#           "display_name": "Department of Navy Acquisition Regulations, Department of Defense",
#           "sortable_name": "Navy Acquisition Regulations, Department of",
#           "slug": "department-of-navy-acquisition-regulations",
#           "cfr_references": [
#             {
#               "title": 48,
#               "chapter": "52"
#             }
#           ]
#         },
#         {
#           "name": "National Geospatial-Intelligence Agency",
#           "short_name": "NGA",
#           "display_name": "National Geospatial-Intelligence Agency, Department of Defense",
#           "sortable_name": "National Geospatial-Intelligence Agency",
#           "slug": "national-geospatial-intelligence-agency",
#           "cfr_references": []
#         },
#         {
#           "name": "Office of the Secretary",
#           "short_name": "",
#           "display_name": "Office of the Secretary, Department of Defense",
#           "sortable_name": "Secretary, Office of the",
#           "slug": "office-of-the-secretary",
#           "cfr_references": [
#             {
#               "title": 32,
#               "chapter": "I"
#             }
#           ]
#         }
#       ],
#       "cfr_references": [
#         {
#           "title": 2,
#           "chapter": "XI"
#         },
#         {
#           "title": 5,
#           "chapter": "XXVI"
#         },
#         {
#           "title": 32,
#           "subtitle": "A"
#         },
#         {
#           "title": 40,
#           "chapter": "VII"
#         }
#       ]
#     },
#     {
#       "name": "Delaware River Basin Commission",
#       "short_name": "DRBC",
#       "display_name": "Delaware River Basin Commission",
#       "sortable_name": "Delaware River Basin Commission",
#       "slug": "delaware-river-basin-commission",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 18,
#           "chapter": "III"
#         }
#       ]
#     },
#     {
#       "name": "Denali Commission",
#       "short_name": "DC",
#       "display_name": "Denali Commission",
#       "sortable_name": "Denali Commission",
#       "slug": "denali-commission",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 45,
#           "chapter": "IX"
#         }
#       ]
#     },
#     {
#       "name": "Office of Director of National Intelligence",
#       "short_name": "ODNI",
#       "display_name": "Office of Director of National Intelligence",
#       "sortable_name": "Director of National Intelligence, Office of",
#       "slug": "national-intelligence-office-of-the-national-director",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 5,
#           "chapter": "IV"
#         },
#         {
#           "title": 32,
#           "chapter": "XVII"
#         }
#       ]
#     },
#     {
#       "name": "National Council on Disability",
#       "short_name": "NCD",
#       "display_name": "National Council on Disability",
#       "sortable_name": "Disability, National Council on",
#       "slug": "national-council-on-disability",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 5,
#           "chapter": "C"
#         },
#         {
#           "title": 34,
#           "chapter": "XII"
#         }
#       ]
#     },
#     {
#       "name": "East-West Foreign Trade Board",
#       "short_name": null,
#       "display_name": "East-West Foreign Trade Board",
#       "sortable_name": "East-West Foreign Trade Board",
#       "slug": "east-west-foreign-trade-board",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 15,
#           "chapter": "XIII"
#         }
#       ]
#     },
#     {
#       "name": "Department of Education",
#       "short_name": "ED",
#       "display_name": "Department of Education",
#       "sortable_name": "Education, Department of",
#       "slug": "education-department",
#       "children": [
#         {
#           "name": "Department of Education Acquisition Regulation",
#           "short_name": "",
#           "display_name": "Department of Education Acquisition Regulation",
#           "sortable_name": "Education Acquisition Regulation, Department of",
#           "slug": "department-of-education-acquisition-regulation",
#           "cfr_references": [
#             {
#               "title": 48,
#               "chapter": "34"
#             }
#           ]
#         },
#         {
#           "name": "Office for Civil Rights",
#           "short_name": "",
#           "display_name": "Office for Civil Rights, Department of Education",
#           "sortable_name": "Civil Rights, Office for",
#           "slug": "office-for-civil-rights",
#           "cfr_references": [
#             {
#               "title": 34,
#               "chapter": "I"
#             }
#           ]
#         },
#         {
#           "name": "Office of and Adult Education Technical Career",
#           "short_name": "",
#           "display_name": "Office of and Adult Education Technical Career, Department of Education",
#           "sortable_name": "Career, Technical, and Adult Education, Office of",
#           "slug": "office-of-and-adult-education-technical-career",
#           "cfr_references": [
#             {
#               "title": 34,
#               "chapter": "IV"
#             }
#           ]
#         },
#         {
#           "name": "Office of Bilingual Education and Minority Languages Affairs",
#           "short_name": "",
#           "display_name": "Office of Bilingual Education and Minority Languages Affairs, Department of Education",
#           "sortable_name": "Bilingual Education and Minority Languages Affairs, Office of",
#           "slug": "office-of-bilingual-education-and-minority-languages-affairs",
#           "cfr_references": [
#             {
#               "title": 34,
#               "chapter": "V"
#             }
#           ]
#         },
#         {
#           "name": "Office of Elementary and Secondary Education",
#           "short_name": "",
#           "display_name": "Office of Elementary and Secondary Education, Department of Education",
#           "sortable_name": "Elementary and Secondary Education, Office of",
#           "slug": "office-of-elementary-and-secondary-education",
#           "cfr_references": [
#             {
#               "title": 34,
#               "chapter": "II"
#             }
#           ]
#         },
#         {
#           "name": "Office of Postsecondary Education",
#           "short_name": null,
#           "display_name": "Office of Postsecondary Education, Department of Education",
#           "sortable_name": "Postsecondary Education, Office of",
#           "slug": "office-of-postsecondary-education",
#           "cfr_references": [
#             {
#               "title": 34,
#               "chapter": "VI"
#             }
#           ]
#         },
#         {
#           "name": "Office of Secretary of Education",
#           "short_name": "",
#           "display_name": "Office of Secretary of Education, Department of Education",
#           "sortable_name": "Secretary of Education, Office of",
#           "slug": "office-of-secretary-of-education",
#           "cfr_references": [
#             {
#               "title": 34,
#               "subtitle": "A"
#             }
#           ]
#         },
#         {
#           "name": "Office of Special Education and Rehabilitative Services",
#           "short_name": "",
#           "display_name": "Office of Special Education and Rehabilitative Services, Department of Education",
#           "sortable_name": "Special Education and Rehabilitative Services, Office of",
#           "slug": "office-of-special-education-and-rehabilitative-services",
#           "cfr_references": [
#             {
#               "title": 34,
#               "chapter": "III"
#             }
#           ]
#         }
#       ],
#       "cfr_references": [
#         {
#           "title": 2,
#           "chapter": "XXXIV"
#         },
#         {
#           "title": 5,
#           "chapter": "LIII"
#         }
#       ]
#     },
#     {
#       "name": "Election Assistance Commission",
#       "short_name": "EAC",
#       "display_name": "Election Assistance Commission",
#       "sortable_name": "Election Assistance Commission",
#       "slug": "election-assistance-commission",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 2,
#           "chapter": "LVIII"
#         },
#         {
#           "title": 11,
#           "chapter": "II"
#         }
#       ]
#     },
#     {
#       "name": "Emergency Oil and Gas Guaranteed Loan Board",
#       "short_name": null,
#       "display_name": "Emergency Oil and Gas Guaranteed Loan Board",
#       "sortable_name": "Emergency Oil and Gas Guaranteed Loan Board",
#       "slug": "emergency-oil-and-gas-guaranteed-loan-board",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 13,
#           "chapter": "V"
#         }
#       ]
#     },
#     {
#       "name": "Emergency Steel Guarantee Loan Board",
#       "short_name": null,
#       "display_name": "Emergency Steel Guarantee Loan Board",
#       "sortable_name": "Emergency Steel Guarantee Loan Board",
#       "slug": "emergency-steel-guarantee-loan-board",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 13,
#           "chapter": "IV"
#         }
#       ]
#     },
#     {
#       "name": "National Commission for Employment Policy",
#       "short_name": "",
#       "display_name": "National Commission for Employment Policy",
#       "sortable_name": "Employment Policy, National Commission for",
#       "slug": "national-commission-for-employment-policy",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 1,
#           "chapter": "IV",
#           "part": "500"
#         }
#       ]
#     },
#     {
#       "name": "Department of Energy",
#       "short_name": "DOE",
#       "display_name": "Department of Energy",
#       "sortable_name": "Energy, Department of",
#       "slug": "energy-department",
#       "children": [
#         {
#           "name": "Federal Energy Regulatory Commission",
#           "short_name": "FERC",
#           "display_name": "Federal Energy Regulatory Commission, Department of Energy",
#           "sortable_name": "Federal Energy Regulatory Commission",
#           "slug": "federal-energy-regulatory-commission",
#           "cfr_references": [
#             {
#               "title": 5,
#               "chapter": "XXIV"
#             },
#             {
#               "title": 18,
#               "chapter": "I"
#             }
#           ]
#         }
#       ],
#       "cfr_references": [
#         {
#           "title": 2,
#           "chapter": "IX"
#         },
#         {
#           "title": 5,
#           "chapter": "XXIII"
#         },
#         {
#           "title": 10,
#           "chapter": "II"
#         },
#         {
#           "title": 10,
#           "chapter": "III"
#         },
#         {
#           "title": 10,
#           "chapter": "X"
#         },
#         {
#           "title": 41,
#           "chapter": "109"
#         },
#         {
#           "title": 48,
#           "chapter": "9"
#         }
#       ]
#     },
#     {
#       "name": "Joint Board for the Enrollment of Actuaries",
#       "short_name": "JBEA",
#       "display_name": "Joint Board for the Enrollment of Actuaries",
#       "sortable_name": "Enrollment of Actuaries, Joint Board for the",
#       "slug": "joint-board-for-enrollment-of-actuaries",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 20,
#           "chapter": "VIII"
#         }
#       ]
#     },
#     {
#       "name": "Environmental Protection Agency",
#       "short_name": "EPA",
#       "display_name": "Environmental Protection Agency",
#       "sortable_name": "Environmental Protection Agency",
#       "slug": "environmental-protection-agency",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 2,
#           "chapter": "XV"
#         },
#         {
#           "title": 5,
#           "chapter": "LIV"
#         },
#         {
#           "title": 40,
#           "chapter": "I"
#         },
#         {
#           "title": 40,
#           "chapter": "IV"
#         },
#         {
#           "title": 40,
#           "chapter": "VII"
#         },
#         {
#           "title": 41,
#           "chapter": "115"
#         },
#         {
#           "title": 48,
#           "chapter": "15"
#         }
#       ]
#     },
#     {
#       "name": "Equal Employment Opportunity Commission",
#       "short_name": "EEOC",
#       "display_name": "Equal Employment Opportunity Commission",
#       "sortable_name": "Equal Employment Opportunity Commission",
#       "slug": "equal-employment-opportunity-commission",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 5,
#           "chapter": "LXII"
#         },
#         {
#           "title": 29,
#           "chapter": "XIV"
#         }
#       ]
#     },
#     {
#       "name": "Executive Office of the President",
#       "short_name": "EOP",
#       "display_name": "Executive Office of the President",
#       "sortable_name": "Executive Office of the President",
#       "slug": "executive-office-of-the-president",
#       "children": [
#         {
#           "name": "Council on Environmental Quality",
#           "short_name": "CEQ",
#           "display_name": "Council on Environmental Quality, Executive Office of the President",
#           "sortable_name": "Environmental Quality, Council on",
#           "slug": "council-on-environmental-quality",
#           "cfr_references": [
#             {
#               "title": 40,
#               "chapter": "V"
#             }
#           ]
#         },
#         {
#           "name": "National Security Council",
#           "short_name": "NSC",
#           "display_name": "National Security Council, Executive Office of the President",
#           "sortable_name": "National Security Council",
#           "slug": "national-security-council",
#           "cfr_references": [
#             {
#               "title": 32,
#               "chapter": "XXI"
#             },
#             {
#               "title": 47,
#               "chapter": "II"
#             }
#           ]
#         },
#         {
#           "name": "Office of Science and Technology Policy",
#           "short_name": "OSTP",
#           "display_name": "Office of Science and Technology Policy, Executive Office of the President",
#           "sortable_name": "Science and Technology Policy, Office of",
#           "slug": "science-and-technology-policy-office",
#           "cfr_references": [
#             {
#               "title": 32,
#               "chapter": "XXIV"
#             },
#             {
#               "title": 47,
#               "chapter": "II"
#             }
#           ]
#         },
#         {
# ...
#       "name": "Tennessee Valley Authority",
#       "short_name": "TVA",
#       "display_name": "Tennessee Valley Authority",
#       "sortable_name": "Tennessee Valley Authority",
#       "slug": "tennessee-valley-authority",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 5,
#           "chapter": "LXIX"
#         },
#         {
#           "title": 18,
#           "chapter": "XIII"
#         }
#       ]
#     },
#     {
#       "name": "Department of Transportation",
#       "short_name": "DOT",
#       "display_name": "Department of Transportation",
#       "sortable_name": "Transportation, Department of",
#       "slug": "transportation-department",
#       "children": [
#         {
#           "name": "Federal Aviation Administration",
#           "short_name": "FAA",
#           "display_name": "Federal Aviation Administration, Department of Transportation",
#           "sortable_name": "Federal Aviation Administration",
#           "slug": "federal-aviation-administration",
#           "cfr_references": [
#             {
#               "title": 14,
#               "chapter": "I"
#             }
#           ]
#         },
#         {
#           "name": "Federal Aviation Administration Commercial Space Transportation",
#           "short_name": "AST",
#           "display_name": "Federal Aviation Administration Commercial Space Transportation, Department of Transportation",
#           "sortable_name": "Commercial Space Transportation, Federal Aviation Administration",
#           "slug": "commercial-space-transportation-office",
#           "cfr_references": [
#             {
#               "title": 14,
#               "chapter": "III"
#             }
#           ]
#         },
#         {
#           "name": "Federal Highway Administration",
#           "short_name": "FHWA",
#           "display_name": "Federal Highway Administration, Department of Transportation",
#           "sortable_name": "Federal Highway Administration",
#           "slug": "federal-highway-administration",
#           "cfr_references": [
#             {
#               "title": 23,
#               "chapter": "I"
#             },
#             {
#               "title": 23,
#               "chapter": "II"
#             }
#           ]
#         },
#         {
#           "name": "Federal Motor Carrier Safety Administration",
#           "short_name": "FMCSA",
#           "display_name": "Federal Motor Carrier Safety Administration, Department of Transportation",
#           "sortable_name": "Federal Motor Carrier Safety Administration",
#           "slug": "federal-motor-carrier-safety-administration",
#           "cfr_references": [
#             {
#               "title": 49,
#               "chapter": "III"
#             }
#           ]
#         },
#         {
#           "name": "Federal Railroad Administration",
#           "short_name": "FRA",
#           "display_name": "Federal Railroad Administration, Department of Transportation",
#           "sortable_name": "Federal Railroad Administration",
#           "slug": "federal-railroad-administration",
#           "cfr_references": [
#             {
#               "title": 49,
#               "chapter": "II"
#             }
#           ]
#         },
#         {
#           "name": "Federal Transit Administration",
#           "short_name": "FTA",
#           "display_name": "Federal Transit Administration, Department of Transportation",
#           "sortable_name": "Federal Transit Administration",
#           "slug": "federal-transit-administration",
#           "cfr_references": [
#             {
#               "title": 49,
#               "chapter": "VI"
#             }
#           ]
#         },
#         {
#           "name": "Great Lakes St. Lawrence Seaway Development Corporation",
#           "short_name": "SAINT",
#           "display_name": "Great Lakes St. Lawrence Seaway Development Corporation, Department of Transportation",
#           "sortable_name": "Great Lakes St. Lawrence Seaway Development Corporation",
#           "slug": "great-lakes-st-lawrence-seaway-development-corporation",
#           "cfr_references": [
#             {
#               "title": 33,
#               "chapter": "IV"
#             }
#           ]
#         },
#         {
#           "name": "Maritime Administration",
#           "short_name": "MARAD",
#           "display_name": "Maritime Administration, Department of Transportation",
#           "sortable_name": "Maritime Administration",
#           "slug": "maritime-administration",
#           "cfr_references": [
#             {
#               "title": 46,
#               "chapter": "II"
#             }
#           ]
#         },
#         {
#           "name": "National Highway Traffic Safety Administration",
#           "short_name": "NHTSA",
#           "display_name": "National Highway Traffic Safety Administration, Department of Transportation",
#           "sortable_name": "National Highway Traffic Safety Administration",
#           "slug": "national-highway-traffic-safety-administration",
#           "cfr_references": [
#             {
#               "title": 23,
#               "chapter": "II"
#             },
#             {
#               "title": 23,
#               "chapter": "III"
#             },
#             {
#               "title": 47,
#               "chapter": "IV"
#             },
#             {
#               "title": 49,
#               "chapter": "V"
#             }
#           ]
#         },
#         {
#           "name": "Office of Secretary (Aviation Proceedings)",
#           "short_name": null,
#           "display_name": "Office of Secretary (Aviation Proceedings), Department of Transportation",
#           "sortable_name": "Secretary (Aviation Proceedings), Office of",
#           "slug": "office-of-secretary-(aviation-proceedings)",
#           "cfr_references": [
#             {
#               "title": 14,
#               "chapter": "II"
#             }
#           ]
#         },
#         {
#           "name": "Office of Secretary of Transportation",
#           "short_name": "",
#           "display_name": "Office of Secretary of Transportation, Department of Transportation",
#           "sortable_name": "Secretary of Transportation, Office of",
#           "slug": "office-of-secretary-of-transportation",
#           "cfr_references": [
#             {
#               "title": 49,
#               "subtitle": "A"
#             }
#           ]
#         },
#         {
#           "name": "Pipeline and Hazardous Materials Safety Administration",
#           "short_name": "PHMSA",
#           "display_name": "Pipeline and Hazardous Materials Safety Administration, Department of Transportation",
#           "sortable_name": "Pipeline and Hazardous Materials Safety Administration",
#           "slug": "pipeline-and-hazardous-materials-safety-administration",
#           "cfr_references": [
#             {
#               "title": 49,
#               "chapter": "I"
#             }
#           ]
#         }
#       ],
#       "cfr_references": [
#         {
#           "title": 2,
#           "chapter": "XII"
#         },
#         {
#           "title": 5,
#           "chapter": "L"
#         },
#         {
#           "title": 44,
#           "chapter": "IV"
#         },
#         {
#           "title": 48,
#           "chapter": "12"
#         }
#       ]
#     },
#     {
#       "name": "Department of Treasury",
#       "short_name": "TREAS",
#       "display_name": "Department of Treasury",
#       "sortable_name": "Treasury, Department of the",
#       "slug": "treasury-department",
#       "children": [
#         {
#           "name": "Alcohol and Tobacco Tax and Trade Bureau",
#           "short_name": "TTB",
#           "display_name": "Alcohol and Tobacco Tax and Trade Bureau, Department of Treasury",
#           "sortable_name": "Alcohol and Tobacco Tax and Trade Bureau",
#           "slug": "alcohol-and-tobacco-tax-and-trade-bureau",
#           "cfr_references": [
#             {
#               "title": 27,
#               "chapter": "I"
#             }
#           ]
#         },
#         {
#           "name": "Bureau of Engraving and Printing",
#           "short_name": "BEP",
#           "display_name": "Bureau of Engraving and Printing, Department of Treasury",
#           "sortable_name": "Engraving and Printing, Bureau of",
#           "slug": "engraving-and-printing-bureau",
#           "cfr_references": [
#             {
#               "title": 31,
#               "chapter": "VI"
#             }
#           ]
#         },
#         {
#           "name": "Bureau of the Fiscal Service",
#           "short_name": "",
#           "display_name": "Bureau of the Fiscal Service, Department of Treasury",
#           "sortable_name": "Fiscal Service, Bureau of",
#           "slug": "bureau-of-the-fiscal-service",
#           "cfr_references": [
#             {
#               "title": 31,
#               "chapter": "II",
#               "subchapter": "A"
#             }
#           ]
#         },
#         {
#           "name": "Community Development Financial Institutions Fund",
#           "short_name": "CDFI",
#           "display_name": "Community Development Financial Institutions Fund, Department of Treasury",
#           "sortable_name": "Community Development Financial Institutions Fund",
#           "slug": "community-development-financial-institutions-fund",
#           "cfr_references": [
#             {
#               "title": 12,
#               "chapter": "XVIII"
#             }
#           ]
#         },
#         {
#           "name": "Comptroller of the Currency",
#           "short_name": "OCC",
#           "display_name": "Comptroller of the Currency, Department of Treasury",
#           "sortable_name": "Comptroller of the Currency",
#           "slug": "comptroller-of-the-currency",
#           "cfr_references": [
#             {
#               "title": 12,
#               "chapter": "I"
#             }
#           ]
#         },
#         {
#           "name": "Financial Crimes Enforcement Network",
#           "short_name": "TD",
#           "display_name": "Financial Crimes Enforcement Network, Department of Treasury",
#           "sortable_name": "Financial Crimes Enforcement Network",
#           "slug": "financial-crimes-enforcement-network",
#           "cfr_references": [
#             {
#               "title": 31,
#               "chapter": "X"
#             }
#           ]
#         },
#         {
#           "name": "Fiscal Service",
#           "short_name": "FS",
#           "display_name": "Fiscal Service, Department of Treasury",
#           "sortable_name": "Fiscal Service",
#           "slug": "fiscal-service",
#           "cfr_references": [
#             {
#               "title": 31,
#               "chapter": "II"
#             }
#           ]
#         },
#         {
#           "name": "Internal Revenue Service",
#           "short_name": "IRS",
#           "display_name": "Internal Revenue Service, Department of Treasury",
#           "sortable_name": "Internal Revenue Service",
#           "slug": "internal-revenue-service",
#           "cfr_references": [
#             {
#               "title": 26,
#               "chapter": "I"
#             }
#           ]
#         },
#         {
#           "name": "Monetary Offices",
#           "short_name": "",
#           "display_name": "Monetary Offices, Department of Treasury",
#           "sortable_name": "Monetary Offices",
#           "slug": "monetary-offices",
#           "cfr_references": [
#             {
#               "title": 31,
#               "chapter": "I"
#             }
#           ]
#         },
#         {
#           "name": "Office of Financial Research",
#           "short_name": "",
#           "display_name": "Office of Financial Research, Department of Treasury",
#           "sortable_name": "Financial Research, Office of",
#           "slug": "office-of-financial-research",
#           "cfr_references": [
#             {
#               "title": 12,
#               "chapter": "XVI"
#             }
#           ]
#         },
#         {
#           "name": "Office of Foreign Assets Control",
#           "short_name": "OFAC",
#           "display_name": "Office of Foreign Assets Control, Department of Treasury",
#           "sortable_name": "Foreign Assets Control, Office of",
#           "slug": "foreign-assets-control-office",
#           "cfr_references": [
#             {
#               "title": 31,
#               "chapter": "V"
#             }
#           ]
#         },
#         {
#           "name": "Office of Investment Security",
#           "short_name": "IIO",
#           "display_name": "Office of Investment Security, Department of Treasury",
#           "sortable_name": "Investment Security, Office of",
#           "slug": "investment-security-office",
#           "cfr_references": [
#             {
#               "title": 31,
#               "chapter": "VIII"
#             }
#           ]
#         },
#         {
#           "name": "Office of Secretary of the Treasury",
#           "short_name": "",
#           "display_name": "Office of Secretary of the Treasury, Department of Treasury",
#           "sortable_name": "Secretary of the Treasury, Office of",
#           "slug": "office-of-secretary-of-the-treasury",
#           "cfr_references": [
#             {
#               "title": 31,
#               "subtitle": "A"
#             }
#           ]
#         }
#       ],
#       "cfr_references": [
#         {
#           "title": 2,
#           "chapter": "X"
#         },
#         {
#           "title": 5,
#           "chapter": "XXI"
#         },
#         {
#           "title": 12,
#           "chapter": "XV"
#         },
#         {
#           "title": 17,
#           "chapter": "IV"
#         },
#         {
#           "title": 31,
#           "chapter": "IX"
#         },
#         {
#           "title": 48,
#           "chapter": "10"
#         }
#       ]
#     },
#     {
#       "name": "Office of United States Trade Representative",
#       "short_name": "USTR",
#       "display_name": "Office of United States Trade Representative",
#       "sortable_name": "United States Trade Representative, Office of",
#       "slug": "trade-representative-office-of-united-states",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 15,
#           "chapter": "XX"
#         }
#       ]
#     },
#     {
#       "name": "Utah Reclamation Mitigation and Conservation Commission",
#       "short_name": "URMCC",
#       "display_name": "Utah Reclamation Mitigation and Conservation Commission",
#       "sortable_name": "Utah Reclamation Mitigation and Conservation Commission",
#       "slug": "utah-reclamation-mitigation-and-conservation-commission",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 43,
#           "chapter": "III"
#         }
#       ]
#     },
#     {
#       "name": "Department of Veterans Affairs",
#       "short_name": "VA",
#       "display_name": "Department of Veterans Affairs",
#       "sortable_name": "Veterans Affairs, Department of",
#       "slug": "veterans-affairs-department",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 2,
#           "chapter": "VIII"
#         },
#         {
#           "title": 38,
#           "chapter": "I"
#         },
#         {
#           "title": 48,
#           "chapter": "8"
#         }
#       ]
#     },
#     {
#       "name": "Office of Vice President of the United States",
#       "short_name": null,
#       "display_name": "Office of Vice President of the United States",
#       "sortable_name": "Vice President of the United States, Office of",
#       "slug": "office-of-vice-president-of-the-united-states",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 32,
#           "chapter": "XXVIII"
#         }
#       ]
#     },
#     {
#       "name": "Water Resources Council",
#       "short_name": null,
#       "display_name": "Water Resources Council",
#       "sortable_name": "Water Resources Council",
#       "slug": "water-resources-council",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 18,
#           "chapter": "VI"
#         }
#       ]
#     },
#     {
#       "name": "President's Commission on White House Fellowships",
#       "short_name": "",
#       "display_name": "President's Commission on White House Fellowships",
#       "sortable_name": "White House Fellowships, President's Commission on",
#       "slug": "president's-commission-on-white-house-fellowships",
#       "children": [],
#       "cfr_references": [
#         {
#           "title": 1,
#           "chapter": "IV",
#           "part": "425"
#         }
#       ]
#     }
#   ]
# }

# %%
flattened_rows = []
#print(data)
#print(data['agencies'])

for agency in data['agencies']:
    parent_name = agency.get('name') # key:value
    #print("parent_name=", parent_name)
    short_name  = agency.get('short_name')
    slug_name   = agency.get('slug')
    children    = agency.get('children')

    # Try to get 'cfr_references' and 'children' from the agency dictionary
    # If it's missing or None, assign an empty list to avoid iteration errors
    parent_cfr_refs = agency.get('cfr_references', [])
    children        = agency.get('children', [])

    # Loop over parent CFR refs, safe to iterate because it's a guaranteed list
    for ref in parent_cfr_refs:
        #print("..cfr_references title=", ref.get('title'), " chapter=", ref.get('chapter'))
        flattened_rows.append({"name": parent_name, 
                              "short_name": short_name, 
                              "slug": slug_name,
                              "title": ref.get('title'),
                              "subtitle": ref.get('subtitle'),
                              "chapter": ref.get('chapter'),
                              "subchapter": ref.get('subchapter'),
                              "part": ref.get("part")
                             })

    # Loop over children CFR refs
    for child in children:
        # child_name = child.get('name')
        for ref in child.get('cfr_references', []):
            flattened_rows.append({"name": parent_name, 
                                  "short_name": short_name, 
                                  "slug": slug_name,
                                  "title": ref.get('title'),
                                  "subtitle": ref.get('subtitle'),
                                  "chapter": ref.get('chapter'),
                                  "subchapter": ref.get('subchapter'),
                                  "part": ref.get("part")
                                 })

# %%
import pandas as pd


agencies_df = pd.DataFrame(flattened_rows)

# Preview the result
print(f"Total CFR references across all agencies and children: {len(agencies_df)}")

filename_csv = agency_metadata_path / "agencies_snapshot.csv"

# Save data frame to a csv file
agencies_df.to_csv(filename_csv, index=False)
print("Saved data frame to", shorten_path(filename_csv))
# Out:
# Total CFR references across all agencies and children: 487
# Saved data frame to ~/repo/doge-data-challenge/agency_metadata/2025-03-27/agencies_snapshot.csv

# %%
agencies_df.head(len(agencies_df))
# Out:
#                                                   name short_name  \
# 0       Administrative Conference of the United States       ACUS
# 1            Advisory Council on Historic Preservation       ACHP
# 2    Special Inspector General for Afghanistan Reco...      SIGAR
# 3                       African Development Foundation      USADF
# 4                       African Development Foundation      USADF
# ..                                                 ...        ...
# 482                     Department of Veterans Affairs         VA
# 483                     Department of Veterans Affairs         VA
# 484      Office of Vice President of the United States       None
# 485                            Water Resources Council       None
# 486  President's Commission on White House Fellowships
#
#                                                   slug  title subtitle  \
# 0       administrative-conference-of-the-united-states      1     None
# 1            advisory-council-on-historic-preservation     36     None
# 2    special-inspector-general-for-afghanistan-reco...      5     None
# 3                       african-development-foundation     22     None
# 4                       african-development-foundation     48     None
# ..                                                 ...    ...      ...
# 482                        veterans-affairs-department     38     None
# 483                        veterans-affairs-department     48     None
# 484      office-of-vice-president-of-the-united-states     32     None
# 485                            water-resources-council     18     None
# 486  president's-commission-on-white-house-fellowships      1     None
#
#      chapter subchapter  part
# 0        III       None  None
# 1       VIII       None  None
# 2    LXXXIII       None  None
# 3         XV       None  None
# 4         57       None  None
# ..       ...        ...   ...
# 482        I       None  None
# 483        8       None  None
# 484   XXVIII       None  None
# 485       VI       None  None
# 486       IV       None   425
#
# [487 rows x 8 columns]

# %%
import sys
print(shorten_path(sys.executable))
# Out:
# ~/Library/Caches/pypoetry/virtualenvs/doge-data-challenge-t_Z9FBnC-py3.10/bin/python
